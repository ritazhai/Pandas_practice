# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(url,sep='\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# need more information about the data 
# what does item_price mean ????
chipo.item_price = chipo.item_price.map(lambda x: np.float(x[1:]))
chipo[chipo['item_price']>10].item_name.nunique()
# Out:
# 31

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
price_per_item = chipo[['item_name', 'item_price']]
price_per_item = round(price_per_item.groupby(by='item_name').mean(),2)
price_per_item.sort_values(by='item_price',ascending=False)
# Out:
#                                        item_price
# item_name
# Bowl                                        14.80
# Steak Salad Bowl                            11.85
# Chicken Salad Bowl                          11.17
# Carnitas Crispy Tacos                       11.14
# Carnitas Salad Bowl                         11.06
# Barbacoa Crispy Tacos                       10.93
# Carnitas Bowl                               10.83
# Steak Bowl                                  10.71
# Barbacoa Salad Bowl                         10.64
# Veggie Soft Tacos                           10.57
# Steak Burrito                               10.47
# Steak Crispy Tacos                          10.21
# Veggie Bowl                                 10.21
# Barbacoa Bowl                               10.19
# Veggie Salad Bowl                           10.14
# Carnitas Burrito                            10.13
# Chicken Bowl                                10.11
# Chicken Burrito                             10.08
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by='item_name')
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# 3422      1373         1  6 Pack Soft Drink
# 553        230         1  6 Pack Soft Drink
# 1916       774         1  6 Pack Soft Drink
# 1922       776         1  6 Pack Soft Drink
# 1937       784         1  6 Pack Soft Drink
# 3836      1537         1  6 Pack Soft Drink
# 298        129         1  6 Pack Soft Drink
# 1976       798         1  6 Pack Soft Drink
# 1167       481         1  6 Pack Soft Drink
# 3875      1554         1  6 Pack Soft Drink
# 1124       465         1  6 Pack Soft Drink
# 3886      1558         1  6 Pack Soft Drink
# 2108       849         1  6 Pack Soft Drink
# 3010      1196         1  6 Pack Soft Drink
# 4535      1803         1  6 Pack Soft Drink
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
# what does item_price mean ????
chipo.sort_values(by = "item_price", ascending = False).head(5)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       35.00
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       33.75

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
chipo_Veggie = chipo[chipo.item_name == "Veggie Salad Bowl"]
len(chipo_Veggie)
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
chipo_Canned = chipo[chipo.item_name == "Canned Soda"]
chipo_Canned = chipo_Canned[chipo.quantity > 1]
len(chipo_Canned)
# Out:
# //anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 20
